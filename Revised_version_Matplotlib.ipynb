# %% [markdown]
# <a href="https://colab.research.google.com/github/Peterpal1/HEALTHIT-MMUST-DATA-SCIENCE/blob/main/Revised_version_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([2,4,34,8,10,12])
y = np.array([2,3,4,5,6,7])
plt.scatter(x,y)

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/academic.csv')
print(data)
# Out:
#        year  students  us_students  undergraduate  graduate  non_degree  \
# 0   1948/49     25464    2403400.0            NaN       NaN         NaN
# 1   1949/50     26433    2445000.0            NaN       NaN         NaN
# 2   1950/51     29813    2281000.0            NaN       NaN         NaN
# 3   1951/52     30462    2102000.0            NaN       NaN         NaN
# 4   1952/53     33675    2134000.0            NaN       NaN         NaN
# ..      ...       ...          ...            ...       ...         ...
# 70  2018/19   1095299   19828000.0       431930.0  377943.0     62341.0
# 71  2019/20   1075496   19720000.0       419321.0  374435.0     58201.0
# 72  2020/21    914095   19744000.0       359787.0  329272.0     21151.0
# 73  2021/22    948519   20327000.0       344532.0  385097.0     34131.0
# 74  2022/23   1057188   18961280.0       347602.0  467027.0     43766.0
#
#          opt
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# ...

# %%
# prompt: connect notebook with drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data2=data.dropna()
print(data2)
# Out:
#        year  students  us_students  undergraduate  graduate  non_degree  \
# 31  1979/80    286343   11570000.0       172520.0   94130.0     16850.0
# 32  1980/81    311882   12097000.0       186660.0   99110.0     21660.0
# 33  1981/82    326299   12372000.0       195150.0  106290.0     21980.0
# 34  1982/83    336985   12426000.0       202760.0  110270.0     20340.0
# 35  1983/84    338894   12465000.0       197480.0  118820.0     19190.0
# 36  1984/85    342113   12242000.0       197640.0  122590.0     17570.0
# 37  1985/86    343777   12247000.0       187660.0  132430.0     19540.0
# 38  1986/87    349609   12504000.0       181230.0  146100.0     17550.0
# 39  1987/88    356187   12767000.0       176669.0  156366.0     18352.0
# 40  1988/89    366354   13055000.0       172551.0  165590.0     21189.0
# 41  1989/90    386851   13539000.0       184527.0  169827.0     24785.0
# 42  1990/91    407529   13819000.0       189900.0  182130.0     26730.0
# ...

# %%
# prompt: using plt create a label for my graph

plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')

# %%
plt.bar(data2['year'],data2['undergraduate'])
plt.xlabel('Year')
plt.ylabel('Undergraduate')
plt.title('Year against Undergradute')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
cv = data2.head()
print(cv)
# Out:
#        year  students  us_students  undergraduate  graduate  non_degree  \
# 31  1979/80    286343   11570000.0       172520.0   94130.0     16850.0
# 32  1980/81    311882   12097000.0       186660.0   99110.0     21660.0
# 33  1981/82    326299   12372000.0       195150.0  106290.0     21980.0
# 34  1982/83    336985   12426000.0       202760.0  110270.0     20340.0
# 35  1983/84    338894   12465000.0       197480.0  118820.0     19190.0
#
#        opt
# 31  2840.0
# 32  3450.0
# 33  2880.0
# 34  3620.0
# 35  3400.0

# %%
plt.plot(cv['year'],cv['undergraduate'])
plt.show()

# %%
plt.bar(cv['year'],cv['undergraduate'])
plt.show()
